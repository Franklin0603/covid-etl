# %%
import pandas as pd
import numpy as np
import requests

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # ETL

# %% [markdown]
# ## extract_covid_data

# %%
url = "https://api.covidtracking.com/v1/us/daily.csv"
response = requests.get(url)

with open('covid_data.csv', 'wb') as f:
    f.write(response.content)
    f.close()

# %%
ls
# Out:
# Covid-ETL.ipynb               email-debug.ipynb
# covid-analysis-and-etl.ipynb  extract.ipynb
# covid_api.ipynb               testing_email_script.ipynb
# covid_data.csv                testing_load.ipynb
# covid_data_logs.ipynb         validate.ipynb

# %%
df = pd.read_csv('covid_data.csv')

# %%
df.head()
# Out:
#        date  states    positive    negative  pending  hospitalizedCurrently  \
# 0  20210307      56  28756489.0  74582825.0  11808.0                40199.0
# 1  20210306      56  28714654.0  74450990.0  11783.0                41401.0
# 2  20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3  20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4  20210303      56  28520365.0  73857281.0  11778.0                45462.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                776361.0          8134.0          45475.0
# 1                775635.0          8409.0          45453.0
# 2                775132.0          8634.0          45373.0
# 3                772351.0          8970.0          45293.0
# 4                770821.0          9359.0          45214.0
#
#    onVentilatorCurrently  ...          lastModified recovered  total  posNeg  \
# 0                 2802.0  ...  2021-03-07T24:00:00Z       NaN      0       0
# 1                 2811.0  ...  2021-03-06T24:00:00Z       NaN      0       0
# 2                 2889.0  ...  2021-03-05T24:00:00Z       NaN      0       0
# 3                 2973.0  ...  2021-03-04T24:00:00Z       NaN      0       0
# 4                 3094.0  ...  2021-03-03T24:00:00Z       NaN      0       0
#
#    deathIncrease hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0            842                  726            131835             41835
# 1           1680                  503            143835             60015
# 2           2221                 2781            271917             68787
# 3           1743                 1530            177957             65487
# 4           2449                 2172            267001             66836
#
#    totalTestResultsIncrease                                      hash
# 0                   1170059  a80d0063822e251249fd9a44730c49cb23defd83
# 1                   1430992  dae5e558c24adb86686bbd58c08cce5f610b8bb0
# 2                   1744417  724844c01659d0103801c57c0f72bf8cc8ab025c
# 3                   1590984  5c549ad30f9abf48dc5de36d20fa707014be1ff3
# 4                   1406795  fef6c425d2b773a9221fe353f13852f3e4a4bfb0
#
# [5 rows x 25 columns]

# %%
df.iloc[1]
# Out:
# date                                                        20210306
# states                                                            56
# positive                                                  28714654.0
# negative                                                  74450990.0
# pending                                                      11783.0
# hospitalizedCurrently                                        41401.0
# hospitalizedCumulative                                      775635.0
# inIcuCurrently                                                8409.0
# inIcuCumulative                                              45453.0
# onVentilatorCurrently                                         2811.0
# onVentilatorCumulative                                        4280.0
# dateChecked                                     2021-03-06T24:00:00Z
# death                                                       514309.0
# hospitalized                                                775635.0
# totalTestResults                                           362655064
# lastModified                                    2021-03-06T24:00:00Z
# recovered                                                        NaN
# total                                                              0
# posNeg                                                             0
# deathIncrease                                                   1680
# hospitalizedIncrease                                             503
# negativeIncrease                                              143835
# positiveIncrease                                               60015
# totalTestResultsIncrease                                     1430992
# hash                        dae5e558c24adb86686bbd58c08cce5f610b8bb0
# Name: 1, dtype: object

# %%
# keep only records that include data from al 56 states
df['states'].value_counts()
# Out:
# 56    357
# 6      12
# 4      12
# 51      9
# 1       9
# 5       5
# 2       5
# 7       2
# 3       2
# 40      1
# 32      1
# 26      1
# 16      1
# 12      1
# 11      1
# 8       1
# Name: states, dtype: int64

# %%
# keep only records that include data from al 56 states
df = df[df['states'] == 56]

# %%
cols = ["recovered", "lastModified", "states", "dateChecked", "total", "posNeg", "hospitalized"]

# Remove unnecessary columns
df.drop(columns = cols , inplace = True)

# %%
# Remove unnecessary columns
cols = ["hash", "date", "positive", "negative", "positiveIncrease", "negativeIncrease", "pending", "hospitalizedCurrently", "hospitalizedIncrease", "hospitalizedCumulative",\
             "inIcuCurrently", "inIcuCumulative", "onVentilatorCurrently", "onVentilatorCumulative", "totalTestResults", "totalTestResultsIncrease","death", "deathIncrease"]

df = df[cols]
df.head()
# Out:
#                                        hash      date    positive    negative  \
# 0  a80d0063822e251249fd9a44730c49cb23defd83  20210307  28756489.0  74582825.0
# 1  dae5e558c24adb86686bbd58c08cce5f610b8bb0  20210306  28714654.0  74450990.0
# 2  724844c01659d0103801c57c0f72bf8cc8ab025c  20210305  28654639.0  74307155.0
# 3  5c549ad30f9abf48dc5de36d20fa707014be1ff3  20210304  28585852.0  74035238.0
# 4  fef6c425d2b773a9221fe353f13852f3e4a4bfb0  20210303  28520365.0  73857281.0
#
#    positiveIncrease  negativeIncrease  pending  hospitalizedCurrently  \
# 0             41835            131835  11808.0                40199.0
# 1             60015            143835  11783.0                41401.0
# 2             68787            271917  12213.0                42541.0
# 3             65487            177957  12405.0                44172.0
# 4             66836            267001  11778.0                45462.0
#
#    hospitalizedIncrease  hospitalizedCumulative  inIcuCurrently  \
# 0                   726                776361.0          8134.0
# 1                   503                775635.0          8409.0
# 2                  2781                775132.0          8634.0
# 3                  1530                772351.0          8970.0
# 4                  2172                770821.0          9359.0
#
#    inIcuCumulative  onVentilatorCurrently  onVentilatorCumulative  \
# 0          45475.0                 2802.0                  4281.0
# 1          45453.0                 2811.0                  4280.0
# 2          45373.0                 2889.0                  4275.0
# 3          45293.0                 2973.0                  4267.0
# 4          45214.0                 3094.0                  4260.0
#
#    totalTestResults  totalTestResultsIncrease     death  deathIncrease
# 0         363825123                   1170059  515151.0            842
# 1         362655064                   1430992  514309.0           1680
# 2         361224072                   1744417  512629.0           2221
# 3         359479655                   1590984  510408.0           1743
# 4         357888671                   1406795  508665.0           2449

# %%
# Rename columns
df.rename(columns ={
    "negative": "pcr_test_negative",
    "positive": "pcr_test_positive"
}, inplace = True)

# %%
df['date'] = df['date'].astype('str')
year  = df['date'].str[0:4]
month = df['date'].str[4:6]
day   = df.date.str[6:8]

df["date"] = pd.to_datetime(year+'-'+month+'-'+day)
df.head()
# Out:
#                                        hash       date  pcr_test_positive  \
# 0  a80d0063822e251249fd9a44730c49cb23defd83 2021-03-07         28756489.0
# 1  dae5e558c24adb86686bbd58c08cce5f610b8bb0 2021-03-06         28714654.0
# 2  724844c01659d0103801c57c0f72bf8cc8ab025c 2021-03-05         28654639.0
# 3  5c549ad30f9abf48dc5de36d20fa707014be1ff3 2021-03-04         28585852.0
# 4  fef6c425d2b773a9221fe353f13852f3e4a4bfb0 2021-03-03         28520365.0
#
#    pcr_test_negative  positiveIncrease  negativeIncrease  pending  \
# 0         74582825.0             41835            131835  11808.0
# 1         74450990.0             60015            143835  11783.0
# 2         74307155.0             68787            271917  12213.0
# 3         74035238.0             65487            177957  12405.0
# 4         73857281.0             66836            267001  11778.0
#
#    hospitalizedCurrently  hospitalizedIncrease  hospitalizedCumulative  \
# 0                40199.0                   726                776361.0
# 1                41401.0                   503                775635.0
# 2                42541.0                  2781                775132.0
# 3                44172.0                  1530                772351.0
# 4                45462.0                  2172                770821.0
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0          8134.0          45475.0                 2802.0
# 1          8409.0          45453.0                 2811.0
# 2          8634.0          45373.0                 2889.0
# 3          8970.0          45293.0                 2973.0
# 4          9359.0          45214.0                 3094.0
#
#    onVentilatorCumulative  totalTestResults  totalTestResultsIncrease  \
# 0                  4281.0         363825123                   1170059
# 1                  4280.0         362655064                   1430992
# 2                  4275.0         361224072                   1744417
# 3                  4267.0         359479655                   1590984
# 4                  4260.0         357888671                   1406795
#
#       death  deathIncrease
# 0  515151.0            842
# 1  514309.0           1680
# 2  512629.0           2221
# 3  510408.0           1743
# 4  508665.0           2449

# %%
# drop nan values
df = df.dropna()

# %%
# export to csv 
df.to_csv("clean_covid_data.csv")

# %%
# Export correlation dataframe
r_squared_scores = pd.DataFrame(["hospitalizedCurrently", "inIcuCurrently", "onVentilatorCurrently"],   columns=["Feature"])
r_squared_scores["R2_Score"] = None
r_squared_scores
# Out:
#                  Feature R2_Score
# 0  hospitalizedCurrently     None
# 1         inIcuCurrently     None
# 2  onVentilatorCurrently     None

# %%
y = np.array(df.loc[:,'deathIncrease']).reshape(-1,1)
i = 0

# %%
# Train a Linear Regression model and calculate R2 score for each feature
for col in ["hospitalizedCurrently", "inIcuCurrently", "onVentilatorCurrently"]:

    x = np.array(df.loc[:, col]).reshape(-1,1)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

    model = LinearRegression()

    model.fit(x_train, y_train)
    r_squared = model.score(x_test, y_test)

    r_squared_scores.R2_Score[i] = r_squared
    i += 1

# Export R2 scores
r_squared_scores.to_csv("R2_Squared_Scores.csv")

# %%
r_squared_scores
# Out:
#                  Feature  R2_Score
# 0  hospitalizedCurrently  0.513929
# 1         inIcuCurrently  0.543345
# 2  onVentilatorCurrently  0.483789
